# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
baseball_dataset=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
baseball_dataset
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
baseball_dataset.shape
# Out:
# (30, 17)

# %%
baseball_dataset.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
baseball_dataset.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
baseball_dataset.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
baseball_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#visualizing the statistics of the column using heatmap
plt.figure(figsize=(20,8))
sns.heatmap(baseball_dataset.describe(), linewidths=0.1, fmt='0.1f', annot=True)
# Out:
# <AxesSubplot:>

# %%
baseball_dataset.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#Distribution of features
plt.figure(figsize=(20,25))
plotnumber=1
for column in baseball_dataset:
    if plotnumber<=17:
        x=plt.subplot(6,3,plotnumber)
        sns.distplot(baseball_dataset[column], hist=False, kde_kws={"shade":True})
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
# Checking the relation between two variable
sns.set_palette('Set1')
plt.figure(figsize=(10,6))
plt.title('Comparision between runs and hits', fontsize=20)
sns.scatterplot(baseball_dataset['R'],baseball_dataset['H'], hue=baseball_dataset['W'])
plt.xlabel('R')
plt.ylabel('H')
# Out:
# Text(0, 0.5, 'H')

# %%
# Checking the relation between Runs and Home Runs
sns.set_palette('Set1')
plt.figure(figsize=(10,6))
plt.title('Comparision between runs and home runs', fontsize=20)
sns.scatterplot(baseball_dataset['R'],baseball_dataset['HR'], hue=baseball_dataset['W'])
plt.xlabel('R')
plt.ylabel('HR')
# Out:
# Text(0, 0.5, 'HR')

# %%
# Checking the relation between Runs and Bat
sns.set_palette('Set1')
plt.figure(figsize=(10,6))
plt.title('Comparision between runs and bat', fontsize=20)
sns.scatterplot(baseball_dataset['R'],baseball_dataset['AB'], hue=baseball_dataset['W'])
plt.xlabel('R')
plt.ylabel('AB')
# Out:
# Text(0, 0.5, 'AB')

# %%
# Checking the relation between Runs and Home Runs
sns.set_palette('Set1')
plt.figure(figsize=(10,6))
plt.title('Comparision between runs and strike out', fontsize=20)
sns.scatterplot(baseball_dataset['R'],baseball_dataset['SO'], hue=baseball_dataset['W'])
plt.xlabel('R')
plt.ylabel('SO')
# Out:
# Text(0, 0.5, 'SO')

# %%
# Checking the relation between Runs and Home Runs
sns.set_palette('hsv')
plt.figure(figsize=(10,6))
plt.title('Comparision between Error and Earned Run Average', fontsize=20)
sns.scatterplot(baseball_dataset['ER'],baseball_dataset['ERA'], hue=baseball_dataset['W'], cmap=('Spectral'))
plt.xlabel('ER')
plt.ylabel('ERA')
# Out:
# Text(0, 0.5, 'ERA')

# %%
# Checking the relation between base and base balls
sns.set_palette('hsv')
plt.figure(figsize=[10,6])
plt.title('At Bat Vs Base on Balls',fontsize =20)
sns.scatterplot(baseball_dataset['AB'],baseball_dataset['BB'],hue=baseball_dataset['E'], cmap=('Spectral'))
plt.xlabel('AB')
plt.ylabel('ERA')
# Out:
# Text(0, 0.5, 'ERA')

# %%
# Boxplot of features
plt.figure(figsize=(18,15))
plotnumber =1
for column in baseball_dataset:
    if plotnumber <=18:
        x = plt.subplot(6,3,plotnumber)
        sns.boxplot(baseball_dataset[column], palette='hsv')
        plt.xlabel(column)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="W", y="BB", data=baseball_dataset,palette='PiYG')
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="W", y="R", data=baseball_dataset,palette='PiYG')
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="W", y="RA", data=baseball_dataset,palette='gist_earth')
plt.title('Bar plot of wins and run average')
plt.show()

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="W", y="ERA", data=baseball_dataset,palette='spring')
plt.title('Bar plot of wins and error run average')
plt.xlabel('W')
plt.ylabel('ERA')
plt.show()

# %%
# Checking the relation between Run Average and ERA
sns.set_palette('Set1')
plt.figure(figsize=[16,8])
plt.title('Comparison between Run Average and Earned Run Average')
sns.stripplot(baseball_dataset['RA'],baseball_dataset['ERA'],hue=baseball_dataset['W'])
plt.xlabel('RA')
plt.ylabel("ERA")
# Out:
# Text(0, 0.5, 'ERA')

# %% [markdown]
# Now let check strikeout show same behavior as ERA with respect to RA

# %%
sns.set_palette('Set1')
plt.figure(figsize=[16,8])
plt.title('Comparison between RA and ERA')
sns.stripplot(baseball_dataset['RA'],baseball_dataset['SO'],hue=baseball_dataset['W'])
plt.xlabel('RA')
plt.ylabel("SO")
# Out:
# Text(0, 0.5, 'SO')

# %%
baseball_dataset['R'].max()
# Out:
# 891

# %%
baseball_dataset.loc[baseball_dataset['R']==891]
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER  ERA  CG  SHO  \
# 5  93  891  5509  1480  308  17  232  570  1151  88  670  609  3.8   7   10
#
#    SV   E
# 5  34  88

# %%
baseball_dataset['HR'].max(),baseball_dataset['BB'].max(),baseball_dataset['2B'].max()
# Out:
# (232, 570, 308)

# %%
sns.jointplot(x="ER", y="W", data=baseball_dataset,palette="Set1")

# %%
sns.jointplot(x="ERA", y="W", data=baseball_dataset,palette="Set1")

# %%
#Let check relationship between saves and wins
plt.figure(figsize=(10,10))
sns.jointplot(x="SV", y="W", data=baseball_dataset, color="purple")

# %%
sns.pairplot(baseball_dataset,hue='W')

# %%
plt.figure(figsize=(17,12))
sns.heatmap(baseball_dataset.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Outlier detection and removal

# %%
from scipy.stats import zscore
z = np.abs(zscore(baseball_dataset))
threshold = 3
df1 = baseball_dataset[(z<3).all(axis = 1)]

# %%
print("\033[1m"+'Shape of dataset after removing outliers :'+"\033[0m",df1.shape)
# Out:
# Shape of dataset after removing outliers : (29, 17)

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((30-29)/30)*100,'%')
# Out:
# Percentage Data Loss : 3.3333333333333335 %

# %% [markdown]
# # Correlation

# %%
df1.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.025885  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.429083  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.771485  0.490752  0.445604 -0.064653
# H   -0.025885  0.429083  0.771485  1.000000  0.525668  0.574467 -0.219890
# 2B   0.384886  0.469293  0.490752  0.525668  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.574467  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219890 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.220426  0.211243 -0.404852  0.336814
# SO   0.142993  0.076079 -0.111364 -0.376569 -0.102043 -0.197629  0.479988
# SB  -0.169503  0.075323  0.373674  0.424369  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.241583 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.278600 -0.224993  0.333731 -0.062094
# ...

# %%
upper_triangle = np.triu(baseball_dataset.corr())
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df1.corr()['W'].drop(['W']).plot(kind='bar',color = 'c')
plt.xlabel('Features')
plt.ylabel('W',fontsize=15)
plt.title('Correlation of features with Target Variable win',fontsize = 18)
plt.show()

# %% [markdown]
# # Standard Scaling

# %%
X=df1.drop(columns =['W'])
Y=df1['W']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()

x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(X_scale)
principle_x=pd.DataFrame(x_new,columns=np.arange(7))

# %%
# checking multicollinearity after applying PCA
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(principle_x.values,i) for i in range(principle_x.shape[1])]
vif['Features']= principle_x.columns
vif
# Out:
#    VIF  Features
# 0  1.0         0
# 1  1.0         1
# 2  1.0         2
# 3  1.0         3
# 4  1.0         4
# 5  1.0         5
# 6  1.0         6

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (20, 7)
# Training target vector size: (20,)
# Test feature matrix size: (9, 7)
# Test target vector size: (9,)

# %%
# Best random state
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=i, test_size=.25)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.9367422856730017 on Random_state 219

# %% [markdown]
# # Linear Regression model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=217, test_size=.25)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [82.39137833 95.46145216 82.63555371 64.03036377 86.65492314 71.29028417
#  82.58111036 72.87617581]
#
#
# Actual Wins:
#  2     81
# 16    98
# 27    79
# 24    63
# 6     87
# 4     74
# 7     81
# 18    68
# Name: W, dtype: int64

# %% [markdown]
# # Linear Regression evaluation matrix

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 2.263490314007388
# Mean squared error : 7.049712183936309
# Root Mean Squared Error: 2.655129410016828
#
#
#  R2 Score :
# 0.9324477347249702

# %%
plt.figure(figsize=(6,5))
y_pred=lin_reg.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] 
for K in range(10):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train,Y_train) 
    y_pred=model.predict(X_test)
    error = sqrt(mean_squared_error(Y_test,y_pred))
    rmse_val.append(error)
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 8.093207028119323
# RMSE value for k=  2 is: 6.126275377421423
# RMSE value for k=  3 is: 5.859465277082316
# RMSE value for k=  4 is: 5.159184770872235
# RMSE value for k=  5 is: 6.17980582219215
# RMSE value for k=  6 is: 6.646323127196805
# RMSE value for k=  7 is: 6.265796364520049
# RMSE value for k=  8 is: 5.896900668995536
# RMSE value for k=  9 is: 6.344653625662289
# RMSE value for k=  10 is: 6.5419798226530785

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(10), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)
